# %%
from joblib import Parallel, delayed
import json
from multiprocessing import Pool
import numpy as np
import pandas as pd
import pickle
from tqdm import tqdm

# Local libraries
import sys
sys.path.insert(1, '../../Data/scripts/strategies')
from baseline import CasesArchive, Explorer
from classifiers import include_splits
from trees import CaseNode

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_dir = '/Users/Javiera/Desktop/Harvard/Code/Data'
features_path = data_dir + '/features/features-2.csv'
clf_path =  data_dir + '/scripts/strategies/classifiers.pkl'
clf_ids_path = data_dir + '/scripts/strategies/clf_ids.csv'
rl_ids_path = data_dir + '/scripts/strategies/rl_ids.csv'
test_ids_path = data_dir + '/scripts/strategies/test_ids.csv'

input_order = ['photo', 'spec', 'color']
settings_path = data_dir + '/scripts/strategies/strategies/settings8.json'

splits = {'rl':rl_ids_path, 'test':test_ids_path}
features = pd.read_csv(features_path)
features = include_splits(features, splits, drop_rows=True)
clf_df = pd.read_pickle(clf_path)

with open(settings_path) as f:
    settings = json.load(f)
root_args = settings['root_args']
tree_args = settings['tree_args']
tree_args['all_clf'] = clf_df

# %%
features
# Out:
#                   id_gaia                    id_sdss       label    K_sdss  \
# 0     3705768362187755776  spec-0847-52426-0599.fits         RRC  0.515388
# 1     2780868247577183104  spec-0418-51817-0365.fits        RRAB  0.515388
# 2     3303225709169790848  spec-3121-54749-0169.fits        RRAB  0.552201
# 3     4410124135237650176  spec-0344-51693-0409.fits        RRAB  0.515388
# 4     1308954745892960768  spec-2808-54524-0607.fits         RRC  0.552201
# 5     4460161874328256896  spec-2530-53881-0559.fits         RRC  0.552201
# 6     3689922166248251264  spec-0292-51609-0470.fits        RRAB  0.441761
# 7     3688533345623140608  spec-0337-51997-0580.fits        RRAB  0.478575
# 8     6909836470632143488  spec-0637-52174-0294.fits         RRC  0.515388
# 9     3706857050498504320  spec-0845-52381-0244.fits         RRC  0.552201
# 10    1406199917940642944  spec-0629-52051-0405.fits        RRAB  0.478575
# 11    1278468556926463104  spec-1386-53116-0023.fits  DSCT_SXPHE  0.625828
# 12     730702511191270784  spec-2359-53826-0591.fits        RRAB  0.441761
# 13    3601122239935174400  spec-0331-52368-0251.fits        RRAB  0.478575
# 14    1353204630008969728  spec-3291-54939-0133.fits        RRAB  0.515388
# 15    3934935099703916928  spec-5859-56065-0452.fits        RRAB  0.502209
# 16    1324961676688539392  spec-5188-55803-0322.fits        RRAB  0.287145
# 17    1783068252895001856  spec-7643-57302-0292.fits         RRC  0.287145
# 18    4565662115253523968  spec-3426-54977-0434.fits         RRC  0.552201
# 19     851899929869875456  spec-3176-54832-0369.fits         RRC  0.552201
# 20    3674578167948957056  spec-3313-54999-0180.fits        RRAB  0.478575
# 21    1191874766336287104  spec-2521-54538-0014.fits         RRC  0.552201
# 22    3897568922883134208  spec-1621-53383-0002.fits        RRAB  0.515388
# 23     148369409017865984  spec-7262-56683-0645.fits     MIRA_SR  0.000000
# 24    1627374412808738304  spec-6802-56456-0256.fits        RRAB  0.287145
# 25    3659055267083504128  spec-0300-51943-0046.fits        RRAB  0.521278
# 26    1510353046667581952  spec-6745-56425-0498.fits         RRC  0.272419
# 2266  ...    0.600904    0.746564    0.748319    0.872529    0.886614
# 2267  ...    0.612053    0.976986    0.616805    0.891876    0.557101
# 2268  ...    0.588351    0.339127    0.401497    0.401976    0.446707
# 2269  ...    0.621372    0.680425    0.586383    0.487352    0.731380
# 2270  ...    0.556335    0.971547    0.662584    0.862953    0.729682
# 2271  ...    0.470589    0.710053    0.529238    0.376704    0.833768
# 2272  ...    0.902035    0.478234    0.780761    0.411228    0.845405
# 2273  ...    0.574833    0.698525    0.729813    0.613402    0.647902
# 2274  ...    0.864762    0.717303    0.811299    0.395814    0.845166
# 2275  ...    0.839544    0.891603    0.896097    0.655108    0.869582
# 2276  ...    0.627836    0.402816    0.565890    0.324050    0.870416
# 2277  ...    0.537954    0.819671    0.502042    0.353882    0.686233
# 2278  ...    0.611040    0.646639    0.725520    0.404502    0.841913
# 2279  ...    0.816771    0.806750    0.789187    0.546618    0.889237
# 2280  ...    0.588351    0.339127    0.401497    0.401976    0.446707
# 2281  ...    0.609852    0.846340    0.693618    0.793925    0.697844
# 2282  ...    0.654424    0.595994    0.592375    0.357939    0.877944
# 2283  ...    0.783324    0.627434    0.601167    0.373484    0.699411
# 2284  ...    0.733150    0.590463    0.447139    0.213560    0.793051
# 2285  ...    0.389796    0.951853    0.625989    0.916630    0.596942
# 2286  ...    0.454308    0.896779    0.645478    0.831999    0.477709
# 2287  ...    0.576894    0.389872    0.246354    0.137663    0.834408
# 2288  ...    0.686166    0.441000    0.345748    0.179702    0.857535
# 2289  ...    0.651670    0.701792    0.670539    0.476715    0.887380
# 2290  ...    0.639049    0.869230    0.754130    0.830628    0.784440
#
#       lengths_gaia     max_time     min_time    z_sdss  split
# 0               25  2331.350724  1689.732893  0.877002   test
# 1                6  2330.702549  1694.854847  0.520935   test
# 2               14  2250.313420  1711.184346  0.591609     rl
# 3               11  2248.256900  1713.489451  0.743860   test
# 4               13  2244.909256  1721.753031  0.542656     rl
# 5               22  2296.144273  1716.745561  0.650571   test
# 6               17  2331.347443  1691.230567  0.667653     rl
# 7               12  2332.347087  1693.481220  0.854600   test
# 8               10  2275.242848  1758.842053  0.660690     rl
# 9               19  2329.274113  1685.227729  0.691201     rl
# 10              12  2277.195392  1724.264105  0.494715     rl
# 11              17  2292.625406  1718.262326  0.566035     rl
# 12               7  2324.111136  1757.011392  0.651825     rl
# 13              17  2326.341438  1680.467863  0.730250   test
# 14              13  2298.374858  1723.510484  0.539490     rl
# 15              19  2330.858503  1684.487661  0.670205     rl
# 16              15  2297.204082  1721.081238  0.711246     rl
# 17               7  2315.872758  1767.602872  0.711246     rl
# 18              12  2282.458640  1719.499932  0.542223   test
# 19              15  2324.627913  1712.546454  0.647050     rl
# 20               6  2242.515194  1707.247298  0.705665     rl
# 21              15  2293.390852  1715.747866  0.723530     rl
# 22              10  2326.097484  1674.719576  0.787444     rl
# 23               9  2254.641247  1743.981323  0.711246     rl
# 24              23  2334.394176  1683.776841  0.711246   test
# 25               6  2243.023942  1703.239529  0.759818     rl
# 26              21  2332.130630  1676.006337  0.711246   test
# 27              16  2322.123950  1716.128075  0.711246     rl
# 28               8  2325.774342  1672.718780  0.711246     rl
# 29               7  2240.888784  1701.950127  0.711246     rl
# ...            ...          ...          ...       ...    ...
# 2261             6  2183.301313  1757.188535  0.589445     rl
# 2262             8  2241.028518  1698.484491  0.732495     rl
# 2263             8  2240.518421  1702.745569  0.675029     rl
# 2264             7  2246.011731  1710.993236  0.831823     rl
# 2265            17  2312.850605  1724.088107  0.700975   test
# 2266            17  2332.342678  1694.477453  0.813308     rl
# 2267            13  2327.856225  1673.978092  0.787995     rl
# 2268             9  2324.469895  1666.598567  0.633742   test
# 2269            11  2328.024628  1680.548920  0.845060   test
# 2270            11  2315.868191  1717.572235  0.816567     rl
# 2271            13  2313.104709  1722.334993  0.711246   test
# 2272            13  2299.205046  1722.328668  0.711246   test
# 2273            10  2315.371465  1767.854160  0.711246   test
# 2274            29  2238.748612  1714.765558  0.711246     rl
# 2275            16  2293.143328  1735.444823  0.694585     rl
# 2276            15  2294.874245  1720.763608  0.627260   test
# 2277            12  2324.866617  1754.433397  0.711246     rl
# 2278            28  2290.373437  1716.762878  0.711246     rl
# 2279            16  2292.441524  1720.093831  0.440906     rl
# 2280             6  2246.435972  1711.993204  0.669344     rl
# 2281            11  2328.850878  1681.728098  0.711246     rl
# 2282            10  2328.596849  1683.549290  0.692726     rl
# 2283            17  2298.714736  1719.321753  0.784835     rl
# 2284            10  2319.358395  1785.190878  0.839504   test
# 2285            22  2326.548564  1751.751876  0.711246   test
# 2286            16  2328.387546  1703.864030  0.638561   test
# 2287            13  2333.351018  1694.809564  0.722641     rl
# 2288            15  2319.868502  1679.656854  0.711246     rl
# 2289            33  2333.365326  1691.748997  0.711246     rl
# 2290            20  2331.855567  1689.237428  0.722282     rl
#
# [2291 rows x 522 columns]

# %%
setup_base = root_args.copy()
setup_base.update(tree_args)
del setup_base['p_thres']

# %%
min_obs = 5
max_obs = features.lengths_gaia.max()
obs_range = list(range(min_obs, max_obs+1))
spec_range = [0,1]
col_range = [0,1]

archive = CasesArchive(features, setup_base)
archive.build_archive(obs_range, spec_range, col_range)
# Out:
#   0%|          | 0/188 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-6e8716b93c36> in <module>
#       6
#       7 archive = CasesArchive(features, setup_base)
# ----> 8 archive.build_archive(obs_range, spec_range, col_range)
#
# ~/Desktop/Harvard/Code/New-framework/pytorch/baseline.py in build_archive(self, obs_range, spec_range, col_range)
#      23         for n_sources_ in tqdm(n_sources):
#      24             setup = CasesArchive.costumize_setup(*n_sources_, self.setup_base)
# ---> 25             self.cases_groups[n_sources_] = self.setup_cases(setup)
#      26
#      27     def costumize_setup(n_obs, n_spec, n_color, setup_base):
#
# ~/Desktop/Harvard/Code/New-framework/pytorch/baseline.py in setup_cases(self, setup)
#      61         for _, features in fset.iterrows():
#      62             setup['all_features'] = features
# ---> 63             case = CaseNode(**setup)
#      64             if case.survey_id in cases:
#      65                 raise ValueError('Duplicate entry for the same bject with gaia id:{}'.format(case.survey_id))
#
# ~/Desktop/Harvard/Code/Data/scripts/strategies/trees.py in __init__(self, n_obs, n_spec, n_color, cost_obs, cost_spec, cost_col, cost_coeff, all_features, all_clf)
#      30         self.set_features()
#      31         self.set_x()
# ---> 32         self.set_prediction()
#      33         self.set_cost()
#      34         self.set_reward()
#
# ~/Desktop/Harvard/Code/Data/scripts/strategies/trees.py in set_prediction(self)
#      47         label_index = np.where(self.clf.classes_== self.label)[0][0]
#      48         self.prediction = self.clf.predict([self.x])[0]
# ---> 49         self.label_prob = self.clf.predict_proba([self.x])[0][label_index]
#      50         self.acc = int(label_index==self.prediction)
#      51
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     594             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba,
#     595                                             lock)
# --> 596             for e in self.estimators_)
#     597
#     598         for proba in all_proba:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     752             tasks = BatchedCalls(itertools.islice(iterator, batch_size),
#     753                                  self._backend.get_nested_backend(),
# --> 754                                  self._pickle_cache)
#     755             if len(tasks) == 0:
#     756                 # No more tasks available in the iterator: tell caller to stop.
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __init__(self, iterator_slice, backend_and_jobs, pickle_cache)
#     208
#     209     def __init__(self, iterator_slice, backend_and_jobs, pickle_cache=None):
# --> 210         self.items = list(iterator_slice)
#     211         self._size = len(self.items)
#     212         if isinstance(backend_and_jobs, tuple):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in <genexpr>(.0)
#     594             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba,
#     595                                             lock)
# --> 596             for e in self.estimators_)
#     597
#     598         for proba in all_proba:
#
# KeyboardInterrupt:

# %%
features.shape
# Out:
# (2291, 522)

# %%
cases_groups = archive.cases_groups
explorer = Explorer(cases_groups, n_neighbors=100)
explorer.fill_memory()
explorer.set_knn()

# %%
def recommend_path(dataset, explorer):
    '''Recommend observational path for each sample in dataset with case-based strategy
    
    Parameters
    ----------
    dataset: pd.DataFrame
        Resulting dataframe from calling `build_sets` with features for each sample.
    explorer: baseline.Explorer
        Costume object for case-based recommendation.
        
    Returns
    -------
    dataset_cases: list
        List with a `CaseNode` object representing the recommended path for each sample in dataset.
        
    '''
    
    dataset_cases = []
    for i, sample in dataset.iterrows():
        n_sources_ = (5,0,0)
        setup = CasesArchive.costumize_setup(*n_sources_, setup_base)
        setup['all_features'] = sample
        case = CaseNode(**setup)
        stop = False

        while not stop:
            step, delta_r = explorer.recommend_step(case)
            if step is None:
                break
            if delta_r>0:
                if (step=='photo') & (case.n_obs<case.max_obs):
                    setup['n_obs'] = setup['n_obs'] + 1
                    case = CaseNode(**setup)
                elif (step=='spectrum') & (case.n_spec==0):
                    setup['n_spec'] = 1
                    case = CaseNode(**setup)
                elif (step=='color') & (case.n_color==0):
                    setup['n_color'] = 1
                    case = CaseNode(**setup)
                else:
                    stop = True
            else:
                stop = True
        dataset_cases.append(case)
    
    return dataset_cases

# %%
cases_val = recommend_path(val, explorer)
cases_test = recommend_path(test, explorer)

# %%
with open(val_save, 'wb') as f:
    pickle.dump(cases_val, f)
    
with open(test_save, 'wb') as f:
    pickle.dump(cases_test, f)

# %%
np.mean([c.reward for c in cases_test]), np.mean([c.reward for c in cases_val])
# Out:
# (0.6848559729973343, 0.7022574139066285)
